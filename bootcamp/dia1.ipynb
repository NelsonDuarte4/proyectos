# %%
cantidad_de_manzanas = 50000
cantidad_de_naranja = 30000
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranja
print("La cantidad de frutas que hay en total: ",cantidad_de_frutas)

frutas_vendidas = 40000
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print("Las frutas que quedan todavia por vender son: ",frutas_restantes)
# Out:
# La cantidad de frutas que hay en total:  80000
# Las frutas que quedan todavia por vender son:  40000

# %%
nombre = "Nelson"
apellido = "Duarte"
print(nombre + ' ' + apellido)

print("Hola, mi nombre es " + nombre +' '+ apellido)

print(f"Hola, mi nombre es {nombre} y mi apellido es {apellido}")
# Out:
# Nelson Duarte
# Hola, mi nombre es Nelson Duarte
# Hola, mi nombre es Nelson y mi apellido es Duarte

# %%
nombre = "Jenny"
apellido = "Villa Santi"
print(f"Hola, yo me llamo {nombre} {apellido} y me gusta los kit kats")
# Out:
# Hola, yo me llamo Jenny Villa Santi y me gusta los kit kats

# %%
nombre = input("Ingrese su nombre")
apellido = input("Ingrese su apellido")
print(f"Mi nombre es {nombre} y mi apellido es {apellido}")
# Out:
# Mi nombre es Nelson y mi apellido es Duarte

# %%
edad = 30
print(type(edad))

edad = "30"
print(type(edad))

edad = 30.1
print(type(edad))

edad = True
print(type(edad))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
cantidad_de_frutas = int(input("cuantas frutas tenes"))
venta_de_frutas = float(input("cuantas frutas vendiste"))
frutas_restantes = cantidad_de_frutas - venta_de_frutas
print(frutas_restantes)
# Out:
# 10.0

# %%
numero1 = int(input("ingresa el primer numero: "))
numero2 = int(input("ingresa el segundo numero: "))
suma = numero1 + numero2
print(suma)
# Out:
# 4

# %%
def saludo():
    nombre = input("Ingrese su nombre: ")
    apellido = input("Ingrese su apellido: ")
    print(f"Hola {nombre} {apellido}, bienvenido al bootcamp")

saludo()
# Out:
# Hola Nelson Duarte, bienvenido al bootcamp

# %%
def pizza():
    masa = input("ingrese la cantidad de harina: ")
    salsa = input("ingrese la cantidad tomates para la salsa: ")
    horno = input("ingrese la cantidad de tiempo 'minutos' que va a estar ene el horno: ")
    print(f"su pizza tendra {masa} kg de harina, luego la salsa tendra {salsa} tomates y por ultimo estara en el horno por {horno} min")

pizza()
pizza()
pizza()
# Out:
# su pizza tendra 2 kg de harina, luego la salsa tendra 5 tomates y por ultimo estara en el horno por 30 min

# %%
def preparar_sanwis(ingredientes):
    print("cortar el pan ")
    print("colocar mayonesa ")
    print("colocar {ingredientes}")
    print("colocar queso ")
    print("colocar tomate ")
    print("colocar lechuga")

preparar_sanwis()
# Out:
# cortar el pan
# colocar mayonesa
# colocar jamon
# colocar queso
# colocar tomate
# colocar lechuga

# %%
def saludar(nombre):
    print("Hola",nombre)

saludar("eduardo")
# Out:
# Hola eduardo

# %%
def sumar(num1, num2):
    calcular = num1 + num2
    print(calcular)

sumar(10,20)
# Out:
# 30

# %%
def tienda(cart1,cart2, cart3, cart4):
    print(f" precio: {cart1} {cart2} {cart3} {cart4}")

tienda(500000,"television","60 pulgadas","grande ")
# Out:
#  precio: 500000 television 60 pulgadas grande

# %%
ingredientes = "jamon"
def preparar_sanwis():
    print(f"estoy usando {ingredientes}")

preparar_sanwis()

print(ingredientes)
# Out:
# estoy usando jamon
# jamon
