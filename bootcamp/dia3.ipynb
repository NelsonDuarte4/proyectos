# %%
def imprimir_saludo():
    print("hola mundo")

imprimir_saludo()

# %%
def imprimir_palabra(): #esto es una funcion
    palabra = "hola" #<--- asi se crea una variable 
    print(palabra)

imprimir_palabra()
# Out:
# hola

# %%
def suma(num1 , num2):
    print(num1 + num2)

suma(2,2)
# Out:
# 4

# %%
letra1 = input("ingresa la primera letra")#esto no anda si esta dentro de la funcion 
letra2 = input("ingresa la segunda letra")

def letras(letra1, letra2):
    if letra1 == letra2:
        print("Las letras son iguales")
    else:
        print("Las letras son diferentes")

letras(letra1,letra2)
# Out:
# Las letras son iguales

# %%
numero = int(input("ingrese un numero")) #Cargamos los valores
letra = input("ingrese una palabra")

def igualdad(numero, letra):
    if len(letra) == numero:
        return True #usamos return para devolver la variable 
    else:
        return False

igualdad(numero, letra)
# Out:
# True

# %%
palabra = input("ingrese la palabra")
letra = input("ingrese la letra que quiera buscar en la palabra")

def buscador(palabra, letra):
    if letra in palabra:
      return(f"[{letra}]")
    else:
      return(letra)

buscador(palabra,letra)
# Out:
# 'i'

# %%
listaglobal = []

for i in range(3):
     palabra = input("ingrese una palabra")
     lista = list(palabra)
     listaglobal.append(lista)


print(listaglobal)
# Out:
# [['h', 'o', 'l', 'a'], ['h', 'o', 'l', 'a'], ['h', 'o', 'l', 'a']]

# %%
lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

def imprimir(lista):
    for i in lista:
        print(i)

imprimir(lista)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
import random
lista_de_palabras = ["tarde","salto","brote","mente","claro"]

palabra_selecionada = random.choice(lista_de_palabras)
print(palabra_selecionada)
vidas = 5

def obtener_fila_verificada(palabra_seleccionada, palabra_ingresada):
    cantidad_de_letras_de_palabra_a_encontrar = 5

    # Creamos una lista vacía para almacenar el resultado de una linea
    letras_verificadas = []

    # Iteramos por cada letra de la palabra ingresada
    for posicion in range(cantidad_de_letras_de_palabra_a_encontrar):

        las_letras_son_iguales = palabra_seleccionada[posicion] == palabra_ingresada[posicion]

        la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_seleccionada

        if las_letras_son_iguales:
            # Guardar las letras que estan en la palabra a encontrar y coinciden en la posicion dentro de corchetes
            letras_verificadas.append("["+palabra_ingresada[posicion]+"]")

        elif la_letra_existe_en_la_palabra:
            # Guardar las letras que no coinciden pero que estan en la palabra a encontrar dentro de parentesis
            letras_verificadas.append("("+palabra_ingresada[posicion]+")")
            
        else:
            letras_verificadas.append(palabra_ingresada[posicion])

    return letras_verificadas




while vidas > 0:
    print(f"Tiene usted {vidas} intentos")
    palabra_ingresada = input("ingrese su palabra")
    print(obtener_fila_verificada(palabra_selecionada,palabra_ingresada))
    vidas = vidas - 1
    if palabra_ingresada == palabra_selecionada:
        print("ganaste crack!")
        vidas = 0
# Out:
# salto
# Tiene usted 5 intentos
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 40
#      38 print(f"Tiene usted {vidas} intentos")
#      39 palabra_ingresada = input("ingrese su palabra")
# ---> 40 print(obtener_fila_verificada(palabra_selecionada,palabra_ingresada))
#      41 vidas = vidas - 1
#      42 if palabra_ingresada == palabra_selecionada:
#
# Cell In[10], line 17, in obtener_fila_verificada(palabra_seleccionada, palabra_ingresada)
#      14 # Iteramos por cada letra de la palabra ingresada
#      15 for posicion in range(cantidad_de_letras_de_palabra_a_encontrar):
# ---> 17     las_letras_son_iguales = palabra_seleccionada[posicion] == palabra_ingresada[posicion]
#      19     la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_seleccionada
#      21     if las_letras_son_iguales:
# ...

# %%
import random
lista_de_palabras = ["tarde","salto","brote","mente","claro"]

seleccion = random.choice(lista_de_palabras)
print(seleccion)
vidas = 5

def obtener_fila_verificada(seleccion, palabra_ingresada):
    cantidad_de_letras_de_palabra_a_encontrar = 5

    # Creamos una lista vacía para almacenar el resultado de una linea
    letras_verificadas = []

    # Iteramos por cada letra de la palabra ingresada
    for posicion in range(cantidad_de_letras_de_palabra_a_encontrar):

        las_letras_son_iguales = seleccion[posicion] == palabra_ingresada[posicion]

        la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in seleccion

        if las_letras_son_iguales:
            # Guardar las letras que estan en la palabra a encontrar y coinciden en la posicion dentro de corchetes
            letras_verificadas.append("["+palabra_ingresada[posicion]+"]")

        elif la_letra_existe_en_la_palabra:
            # Guardar las letras que no coinciden pero que estan en la palabra a encontrar dentro de parentesis
            letras_verificadas.append("("+palabra_ingresada[posicion]+")")
            
        else:
            letras_verificadas.append(palabra_ingresada[posicion])

    return letras_verificadas




while vidas > 0:
    print(f"Tiene usted {vidas} intentos")
    palabra_ingresada = input("ingrese su palabra")
    print(obtener_fila_verificada(seleccion,palabra_ingresada))
    vidas = vidas - 1
    if palabra_ingresada == seleccion:
        print("ganaste crack!")
        vidas = 0
# Out:
# claro
# Tiene usted 5 intentos
# ['(a)', '(r)', 'b', '(o)', '(l)']
# Tiene usted 4 intentos
# ['[c]', '[l]', '[a]', '[r]', '[o]']
# ganaste crack!
